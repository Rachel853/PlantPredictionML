# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
df = pd.read_csv('../src/data/GLC24_PA_metadata_test.csv')
print(df.to_string())
# Out:
#             lon        lat  year  geoUncertaintyInM  areaInM2         region                 country  surveyId
# 0     10.033550  57.120810  2019               10.0    707.00    CONTINENTAL                 Denmark       642
# 1      7.333000  46.229970  2019                NaN     10.00         ALPINE             Switzerland      1792
# 2      1.843658  42.580060  2018                0.0      -inf         ALPINE                  France      3256
# 3     11.720090  46.261490  2021               10.0     35.00         ALPINE                   Italy      3855
# 4      9.361870  55.902450  2017               10.0     79.00    CONTINENTAL                 Denmark      4889
# 5     10.010010  57.122950  2019               10.0    707.00    CONTINENTAL                 Denmark      5884
# 6     13.750190  42.047370  2017               20.0     10.00  MEDITERRANEAN                   Italy      6955
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
import pandas as pd
df = pd.read_csv('../src/data/GLC24_PA_metadata_test.csv')
print(df.to_string())
# Out:
#             lon        lat  year  geoUncertaintyInM  areaInM2         region                 country  surveyId
# 0     10.033550  57.120810  2019               10.0    707.00    CONTINENTAL                 Denmark       642
# 1      7.333000  46.229970  2019                NaN     10.00         ALPINE             Switzerland      1792
# 2      1.843658  42.580060  2018                0.0      -inf         ALPINE                  France      3256
# 3     11.720090  46.261490  2021               10.0     35.00         ALPINE                   Italy      3855
# 4      9.361870  55.902450  2017               10.0     79.00    CONTINENTAL                 Denmark      4889
# 5     10.010010  57.122950  2019               10.0    707.00    CONTINENTAL                 Denmark      5884
# 6     13.750190  42.047370  2017               20.0     10.00  MEDITERRANEAN                   Italy      6955
# ...
